# %%
import numpy as np
import pandas as pd
import xarray as xr

# %%
Chacaltaya = [-16.2,-68.12]
outpath = '/home/emroy/GP/ACP/scripts/final/paper_staging/VariabilityInversion/Model_data/CHC/GEOSChem/Base/'

# %%
Chac_path_14p1 = '/net/fs03/d0/emroy/GCrundir/run0018/OutputDir/2014_2015/GEOSChem.SpeciesConc.201*01_0000z.nc4'
r18_1415 = xr.open_mfdataset(Chac_path_14p1)
r18_1415.isel(lev=19)['SpeciesConcVV_Hg0'].sel(lat=Chacaltaya[0],lon=Chacaltaya[1],method='nearest').to_netcdf(outpath+'GEOSChem.SpeciesConc.alltime_d.14p1.nc4')
# Out:
# /home/emroy/.conda/envs/geos_22/lib/python3.10/site-packages/xarray/core/indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(
# /home/emroy/.conda/envs/geos_22/lib/python3.10/site-packages/xarray/core/indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(

# %%
import pandas as pd
import function as f

obs = f.read_obs('GunnPoint')
#obs = obs.set_index('date')

# %%
obs
